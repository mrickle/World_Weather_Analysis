# %%
import random
import pandas as pd
import numpy as np
# Import timeit.
import timeit
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 2 | qostanay
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | camacha
# Processing Record 4 of Set 2 | rikitea
# Processing Record 5 of Set 2 | tomatlan
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | spokane
# Processing Record 8 of Set 2 | klyuchi
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 2 | coquimbo
# Processing Record 12 of Set 2 | boa vista
# Processing Record 13 of Set 2 | narsaq
# Processing Record 14 of Set 2 | nouakchott
# Processing Record 15 of Set 2 | porto novo
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | gao
# Processing Record 18 of Set 2 | lazaro cardenas
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | carnarvon
# Processing Record 22 of Set 2 | mount gambier
# Processing Record 23 of Set 2 | edd
# Processing Record 24 of Set 2 | piney green
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | hit
# Processing Record 27 of Set 2 | ridgecrest
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | bluff
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | tazovskiy
# Processing Record 32 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 2 | punta arenas
# Processing Record 34 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 2 | sobolevo
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | anadyr
# Processing Record 38 of Set 2 | neuquen
# Processing Record 39 of Set 2 | dunedin
# Processing Record 40 of Set 2 | homer
# Processing Record 41 of Set 2 | olafsvik
# Processing Record 42 of Set 2 | gorgan
# Processing Record 43 of Set 2 | chapleau
# Processing Record 44 of Set 2 | los llanos de aridane
# Processing Record 45 of Set 2 | mandalgovi
# Processing Record 46 of Set 2 | souillac
# Processing Record 47 of Set 2 | puerto baquerizo moreno
# Processing Record 48 of Set 2 | mayakonda
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | clyde river
# Processing Record 1 of Set 3 | ushuaia
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | saint-joseph
# Processing Record 4 of Set 3 | metro
# Processing Record 5 of Set 3 | nizhnekamsk
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | ondangwa
# Processing Record 8 of Set 3 | ternate
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | saint george
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | fereydun kenar
# Processing Record 14 of Set 3 | tuktoyaktuk
# Processing Record 15 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 17 of Set 3 | mackay
# Processing Record 18 of Set 3 | busselton
# Processing Record 19 of Set 3 | thompson
# Processing Record 20 of Set 3 | sitka
# Processing Record 21 of Set 3 | batemans bay
# Processing Record 22 of Set 3 | amapa
# Processing Record 23 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 3 | kitimat
# Processing Record 25 of Set 3 | victoria
# Processing Record 26 of Set 3 | mar del plata
# Processing Record 27 of Set 3 | tasiilaq
# Processing Record 28 of Set 3 | hobyo
# Processing Record 29 of Set 3 | inuvik
# Processing Record 30 of Set 3 | alofi
# Processing Record 31 of Set 3 | neokhorion
# Processing Record 32 of Set 3 | neiafu
# Processing Record 33 of Set 3 | oktyabrskiy
# Processing Record 34 of Set 3 | karpushikha
# Processing Record 35 of Set 3 | poronaysk
# Processing Record 36 of Set 3 | cape town
# Processing Record 37 of Set 3 | bethel
# Processing Record 38 of Set 3 | coahuayana
# Processing Record 39 of Set 3 | fairbanks
# Processing Record 40 of Set 3 | luderitz
# Processing Record 41 of Set 3 | ostrovnoy
# Processing Record 42 of Set 3 | cherskiy
# Processing Record 43 of Set 3 | barrow
# Processing Record 44 of Set 3 | waingapu
# Processing Record 45 of Set 3 | mataura
# Processing Record 46 of Set 3 | sao joao da barra
# Processing Record 47 of Set 3 | port alfred
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | dilla
# Processing Record 50 of Set 3 | geraldton
# Processing Record 1 of Set 4 | novaya igirma
# Processing Record 2 of Set 4 | teguise
# Processing Record 3 of Set 4 | lima
# Processing Record 4 of Set 4 | chuy
# Processing Record 5 of Set 4 | vestmannaeyjar
# Processing Record 6 of Set 4 | kahului
# Processing Record 7 of Set 4 | hithadhoo
# Processing Record 8 of Set 4 | lieksa
# Processing Record 9 of Set 4 | qasigiannguit
# Processing Record 10 of Set 4 | hobart
# Processing Record 11 of Set 4 | talnakh
# Processing Record 12 of Set 4 | bredasdorp
# Processing Record 13 of Set 4 | broken hill
# Processing Record 14 of Set 4 | harper
# Processing Record 15 of Set 4 | chokurdakh
# Processing Record 16 of Set 4 | chipinge
# Processing Record 17 of Set 4 | rundu
# Processing Record 18 of Set 4 | rawson
# Processing Record 19 of Set 4 | kavieng
# Processing Record 20 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 4 | elizabeth city
# Processing Record 22 of Set 4 | pui
# Processing Record 23 of Set 4 | tiksi
# Processing Record 24 of Set 4 | clyde
# Processing Record 25 of Set 4 | shahdadkot
# Processing Record 26 of Set 4 | batsfjord
# Processing Record 27 of Set 4 | dingle
# Processing Record 28 of Set 4 | klaksvik
# Processing Record 29 of Set 4 | nizhniy tsasuchey
# Processing Record 30 of Set 4 | vila velha
# Processing Record 31 of Set 4 | jalu
# Processing Record 32 of Set 4 | touros
# Processing Record 33 of Set 4 | kamina
# Processing Record 34 of Set 4 | bonfim
# Processing Record 35 of Set 4 | dicabisagan
# Processing Record 36 of Set 4 | teya
# Processing Record 37 of Set 4 | yellowknife
# Processing Record 38 of Set 4 | bengkulu
# Processing Record 39 of Set 4 | taltal
# Processing Record 40 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 4 | beringovskiy
# Processing Record 42 of Set 4 | zhelyabovka
# Processing Record 43 of Set 4 | port hardy
# Processing Record 44 of Set 4 | goderich
# Processing Record 45 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 4 | bershet
# Processing Record 47 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 4 | namibe
# Processing Record 49 of Set 4 | butaritari
# Processing Record 50 of Set 4 | galveston
# Processing Record 1 of Set 5 | airai
# Processing Record 2 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 5 | padang
# Processing Record 4 of Set 5 | hilo
# Processing Record 5 of Set 5 | new norfolk
# Processing Record 6 of Set 5 | broome
# Processing Record 7 of Set 5 | da lat
# Processing Record 8 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 9 of Set 5 | la ronge
# Processing Record 10 of Set 5 | omsukchan
# Processing Record 11 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 5 | gold coast
# Processing Record 13 of Set 5 | waddan
# Processing Record 14 of Set 5 | udachnyy
# Processing Record 15 of Set 5 | varkkallai
# Processing Record 16 of Set 5 | helena
# Processing Record 17 of Set 5 | port-gentil
# Processing Record 18 of Set 5 | alpine
# Processing Record 19 of Set 5 | dikson
# Processing Record 20 of Set 5 | carutapera
# Processing Record 21 of Set 5 | provideniya
# Processing Record 22 of Set 5 | kodinsk
# Processing Record 23 of Set 5 | boueni
# Processing Record 24 of Set 5 | berdigestyakh
# Processing Record 25 of Set 5 | kruisfontein
# Processing Record 26 of Set 5 | saldanha
# Processing Record 27 of Set 5 | terrasini
# Processing Record 28 of Set 5 | bull savanna
# Processing Record 29 of Set 5 | aswan
# Processing Record 30 of Set 5 | shenjiamen
# Processing Record 31 of Set 5 | ahuimanu
# Processing Record 32 of Set 5 | lata
# Processing Record 33 of Set 5 | kavaratti
# Processing Record 34 of Set 5 | laguna
# Processing Record 35 of Set 5 | vanimo
# Processing Record 36 of Set 5 | khani
# Processing Record 37 of Set 5 | port blair
# Processing Record 38 of Set 5 | ponta do sol
# Processing Record 39 of Set 5 | shache
# Processing Record 40 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 5 | turayf
# Processing Record 42 of Set 5 | komsomolskiy
# Processing Record 43 of Set 5 | nome
# Processing Record 44 of Set 5 | korla
# Processing Record 45 of Set 5 | kuandian
# Processing Record 46 of Set 5 | linhares
# Processing Record 47 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 5 | aklavik
# Processing Record 49 of Set 5 | adrar
# Processing Record 50 of Set 5 | kjollefjord
# Processing Record 1 of Set 6 | mayahi
# Processing Record 2 of Set 6 | ginda
# Processing Record 3 of Set 6 | ponta delgada
# Processing Record 4 of Set 6 | hohhot
# Processing Record 5 of Set 6 | maniitsoq
# Processing Record 6 of Set 6 | tomball
# Processing Record 7 of Set 6 | kapaa
# Processing Record 8 of Set 6 | san patricio
# Processing Record 9 of Set 6 | sligo
# Processing Record 10 of Set 6 | asau
# Processing Record 11 of Set 6 | constitucion
# Processing Record 12 of Set 6 | fengrun
# Processing Record 13 of Set 6 | guhagar
# Processing Record 14 of Set 6 | takoradi
# Processing Record 15 of Set 6 | dhidhdhoo
# Processing Record 16 of Set 6 | halifax
# Processing Record 17 of Set 6 | belaya gora
# Processing Record 18 of Set 6 | dom pedrito
# Processing Record 19 of Set 6 | salinopolis
# Processing Record 20 of Set 6 | sambava
# Processing Record 21 of Set 6 | cabo san lucas
# Processing Record 22 of Set 6 | lavrentiya
# Processing Record 23 of Set 6 | cabras
# Processing Record 24 of Set 6 | kiama
# Processing Record 25 of Set 6 | byron bay
# Processing Record 26 of Set 6 | norman wells
# Processing Record 27 of Set 6 | marawi
# Processing Record 28 of Set 6 | quatre cocos
# Processing Record 29 of Set 6 | valparaiso
# Processing Record 30 of Set 6 | normandin
# Processing Record 31 of Set 6 | erenhot
# Processing Record 32 of Set 6 | esperance
# Processing Record 33 of Set 6 | nadvoitsy
# Processing Record 34 of Set 6 | sungaipenuh
# Processing Record 35 of Set 6 | cockburn town
# Processing Record 36 of Set 6 | gundlupet
# Processing Record 37 of Set 6 | nikolskoye
# Processing Record 38 of Set 6 | katubao
# Processing Record 39 of Set 6 | saint-philippe
# Processing Record 40 of Set 6 | waterloo
# Processing Record 41 of Set 6 | sorland
# Processing Record 42 of Set 6 | port elizabeth
# Processing Record 43 of Set 6 | castro
# Processing Record 44 of Set 6 | opuwo
# Processing Record 45 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 6 | whitehorse
# Processing Record 47 of Set 6 | constantine
# Processing Record 48 of Set 6 | rawah
# Processing Record 49 of Set 6 | burnie
# Processing Record 50 of Set 6 | saint-pierre
# Processing Record 1 of Set 7 | saint-francois
# Processing Record 2 of Set 7 | urumqi
# Processing Record 3 of Set 7 | guarapari
# Processing Record 4 of Set 7 | berlevag
# Processing Record 5 of Set 7 | salalah
# Processing Record 6 of Set 7 | cutervo
# Processing Record 7 of Set 7 | san carlos de bariloche
# Processing Record 8 of Set 7 | skjervoy
# Processing Record 9 of Set 7 | brae
# Processing Record 10 of Set 7 | hofn
# Processing Record 11 of Set 7 | victor harbor
# Processing Record 12 of Set 7 | cururupu
# Processing Record 13 of Set 7 | danlugan
# Processing Record 14 of Set 7 | nanortalik
# Processing Record 15 of Set 7 | bosaso
# Processing Record 16 of Set 7 | tanete
# Processing Record 17 of Set 7 | uhlove
# Processing Record 18 of Set 7 | lagoa
# Processing Record 19 of Set 7 | taranagar
# Processing Record 20 of Set 7 | olga
# Processing Record 21 of Set 7 | sukhumi
# Processing Record 22 of Set 7 | cayenne
# Processing Record 23 of Set 7 | manokwari
# Processing Record 24 of Set 7 | saint-andre-avellin
# Processing Record 25 of Set 7 | pimentel
# Processing Record 26 of Set 7 | ginir
# Processing Record 27 of Set 7 | khakhea
# Processing Record 28 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 7 | ilulissat
# Processing Record 30 of Set 7 | dalby
# Processing Record 31 of Set 7 | mbeya
# Processing Record 32 of Set 7 | yanggu
# Processing Record 33 of Set 7 | kampong chhnang
# Processing Record 34 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 7 | vardo
# Processing Record 36 of Set 7 | margate
# Processing Record 37 of Set 7 | meulaboh
# Processing Record 38 of Set 7 | joinville
# Processing Record 39 of Set 7 | severo-kurilsk
# Processing Record 40 of Set 7 | lumby
# Processing Record 41 of Set 7 | bethanien
# Processing Record 42 of Set 7 | porangatu
# Processing Record 43 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 7 | northam
# Processing Record 45 of Set 7 | gebre guracha
# Processing Record 46 of Set 7 | tual
# Processing Record 47 of Set 7 | adolfo lopez mateos
# Processing Record 48 of Set 7 | bambous virieux
# Processing Record 49 of Set 7 | pangkalanbuun
# Processing Record 50 of Set 7 | dubna
# Processing Record 1 of Set 8 | alice springs
# Processing Record 2 of Set 8 | hare bay
# Processing Record 3 of Set 8 | cartagena
# Processing Record 4 of Set 8 | volsk
# Processing Record 5 of Set 8 | east london
# Processing Record 6 of Set 8 | pevek
# Processing Record 7 of Set 8 | kudahuvadhoo
# Processing Record 8 of Set 8 | katsuura
# Processing Record 9 of Set 8 | grand-lahou
# Processing Record 10 of Set 8 | canon city
# Processing Record 11 of Set 8 | gorontalo
# Processing Record 12 of Set 8 | leningradskiy
# Processing Record 13 of Set 8 | maneadero
# Processing Record 14 of Set 8 | ulaangom
# Processing Record 15 of Set 8 | pangnirtung
# Processing Record 16 of Set 8 | novokayakent
# Processing Record 17 of Set 8 | gat
# Processing Record 18 of Set 8 | ankang
# Processing Record 19 of Set 8 | haicheng
# Processing Record 20 of Set 8 | grindavik
# Processing Record 21 of Set 8 | kaitangata
# Processing Record 22 of Set 8 | chapais
# Processing Record 23 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 8 | pa sang
# Processing Record 25 of Set 8 | umea
# Processing Record 26 of Set 8 | maridi
# Processing Record 27 of Set 8 | kibaya
# Processing Record 28 of Set 8 | santo amaro da imperatriz
# Processing Record 29 of Set 8 | singarayakonda
# Processing Record 30 of Set 8 | ishigaki
# Processing Record 31 of Set 8 | dwarka
# Processing Record 32 of Set 8 | bathsheba
# Processing Record 33 of Set 8 | bakel
# Processing Record 34 of Set 8 | guerrero negro
# Processing Record 35 of Set 8 | puerto del rosario
# Processing Record 36 of Set 8 | san andres
# Processing Record 37 of Set 8 | fare
# Processing Record 38 of Set 8 | vila franca do campo
# Processing Record 39 of Set 8 | ahipara
# Processing Record 40 of Set 8 | ilo
# Processing Record 41 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 8 | pacific grove
# Processing Record 43 of Set 8 | pangai
# Processing Record 44 of Set 8 | redcar
# Processing Record 45 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 46 of Set 8 | mizdah
# Processing Record 47 of Set 8 | sabang
# Processing Record 48 of Set 8 | cidreira
# Processing Record 49 of Set 8 | dalianwan
# Processing Record 50 of Set 8 | jijiga
# Processing Record 1 of Set 9 | zaranj
# Processing Record 2 of Set 9 | san rafael del sur
# Processing Record 3 of Set 9 | polunochnoye
# Processing Record 4 of Set 9 | lubartow
# Processing Record 5 of Set 9 | ukiah
# Processing Record 6 of Set 9 | puri
# Processing Record 7 of Set 9 | moose factory
# Processing Record 8 of Set 9 | kotturu
# Processing Record 9 of Set 9 | mier
# Processing Record 10 of Set 9 | taoudenni
# Processing Record 11 of Set 9 | sao miguel do araguaia
# Processing Record 12 of Set 9 | san cristobal
# Processing Record 13 of Set 9 | clinton
# Processing Record 14 of Set 9 | borodino
# Processing Record 15 of Set 9 | higuey
# City not found. Skipping...
# Processing Record 16 of Set 9 | kefar shemaryahu
# Processing Record 17 of Set 9 | roma
# Processing Record 18 of Set 9 | tchibanga
# Processing Record 19 of Set 9 | ouro preto do oeste
# Processing Record 20 of Set 9 | palmer
# Processing Record 21 of Set 9 | bitkine
# Processing Record 22 of Set 9 | suez
# Processing Record 23 of Set 9 | baghmara
# Processing Record 24 of Set 9 | maldonado
# Processing Record 25 of Set 9 | antofagasta
# Processing Record 26 of Set 9 | creemore
# Processing Record 27 of Set 9 | wamba
# Processing Record 28 of Set 9 | nichinan
# Processing Record 29 of Set 9 | athabasca
# Processing Record 30 of Set 9 | yerofey pavlovich
# Processing Record 31 of Set 9 | ilebo
# Processing Record 32 of Set 9 | iqaluit
# Processing Record 33 of Set 9 | shancheng
# Processing Record 34 of Set 9 | zabinka
# City not found. Skipping...
# Processing Record 35 of Set 9 | portland
# Processing Record 36 of Set 9 | najran
# Processing Record 37 of Set 9 | rio gallegos
# Processing Record 38 of Set 9 | selaphum
# Processing Record 39 of Set 9 | andapa
# Processing Record 40 of Set 9 | hovd
# Processing Record 41 of Set 9 | yeppoon
# Processing Record 42 of Set 9 | port keats
# Processing Record 43 of Set 9 | bara
# Processing Record 44 of Set 9 | lompoc
# Processing Record 45 of Set 9 | izumo
# Processing Record 46 of Set 9 | ixtapa
# Processing Record 47 of Set 9 | buala
# Processing Record 48 of Set 9 | marabba
# Processing Record 49 of Set 9 | bugko
# Processing Record 50 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 1 of Set 10 | itarema
# Processing Record 2 of Set 10 | yangjiang
# Processing Record 3 of Set 10 | port lincoln
# Processing Record 4 of Set 10 | alvinopolis
# Processing Record 5 of Set 10 | shimoda
# Processing Record 6 of Set 10 | carupano
# Processing Record 7 of Set 10 | codrington
# Processing Record 8 of Set 10 | hasaki
# Processing Record 9 of Set 10 | katherine
# Processing Record 10 of Set 10 | tabou
# Processing Record 11 of Set 10 | half moon bay
# Processing Record 12 of Set 10 | walvis bay
# Processing Record 13 of Set 10 | riberalta
# Processing Record 14 of Set 10 | osa
# Processing Record 15 of Set 10 | mitsamiouli
# Processing Record 16 of Set 10 | ballina
# Processing Record 17 of Set 10 | ironton
# Processing Record 18 of Set 10 | rocha
# Processing Record 19 of Set 10 | huaral
# Processing Record 20 of Set 10 | okato
# Processing Record 21 of Set 10 | verkhoyansk
# Processing Record 22 of Set 10 | bileca
# Processing Record 23 of Set 10 | yefira
# City not found. Skipping...
# Processing Record 24 of Set 10 | pontianak
# Processing Record 25 of Set 10 | te anau
# Processing Record 26 of Set 10 | puurmani
# Processing Record 27 of Set 10 | ribeira grande
# Processing Record 28 of Set 10 | sept-iles
# Processing Record 29 of Set 10 | seoul
# Processing Record 30 of Set 10 | mogadishu
# Processing Record 31 of Set 10 | contai
# Processing Record 32 of Set 10 | valdez
# Processing Record 33 of Set 10 | kirillov
# Processing Record 34 of Set 10 | coruripe
# Processing Record 35 of Set 10 | teixeira
# Processing Record 36 of Set 10 | manuk mangkaw
# Processing Record 37 of Set 10 | urucara
# Processing Record 38 of Set 10 | arlit
# Processing Record 39 of Set 10 | sangar
# Processing Record 40 of Set 10 | balykshi
# Processing Record 41 of Set 10 | torbay
# Processing Record 42 of Set 10 | muli
# Processing Record 43 of Set 10 | nelson bay
# Processing Record 44 of Set 10 | krasnoznamensk
# Processing Record 45 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 46 of Set 10 | ancud
# Processing Record 47 of Set 10 | aporawan
# City not found. Skipping...
# Processing Record 48 of Set 10 | tucupita
# Processing Record 49 of Set 10 | reconquista
# Processing Record 50 of Set 10 | soledade
# Processing Record 1 of Set 11 | esil
# Processing Record 2 of Set 11 | terrace
# Processing Record 3 of Set 11 | jiexiu
# Processing Record 4 of Set 11 | yelan-koleno
# Processing Record 5 of Set 11 | antibes
# Processing Record 6 of Set 11 | nizwa
# Processing Record 7 of Set 11 | praia da vitoria
# Processing Record 8 of Set 11 | atasu
# Processing Record 9 of Set 11 | college
# Processing Record 10 of Set 11 | malpe
# Processing Record 11 of Set 11 | viedma
# Processing Record 12 of Set 11 | talara
# Processing Record 13 of Set 11 | khorramshahr
# Processing Record 14 of Set 11 | tahe
# Processing Record 15 of Set 11 | hami
# Processing Record 16 of Set 11 | inhambane
# Processing Record 17 of Set 11 | takaka
# Processing Record 18 of Set 11 | pascagoula
# Processing Record 19 of Set 11 | calmeca
# Processing Record 20 of Set 11 | leatherhead
# Processing Record 21 of Set 11 | atar
# Processing Record 22 of Set 11 | contamana
# Processing Record 23 of Set 11 | deputatskiy
# Processing Record 24 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 11 | kardymovo
# Processing Record 26 of Set 11 | namatanai
# Processing Record 27 of Set 11 | gospic
# Processing Record 28 of Set 11 | olinda
# Processing Record 29 of Set 11 | wajima
# Processing Record 30 of Set 11 | krasnoselkup
# Processing Record 31 of Set 11 | igarape-miri
# City not found. Skipping...
# Processing Record 32 of Set 11 | ambilobe
# Processing Record 33 of Set 11 | sadiqabad
# Processing Record 34 of Set 11 | raga
# Processing Record 35 of Set 11 | gorin
# Processing Record 36 of Set 11 | loandjili
# Processing Record 37 of Set 11 | krasnaya gorbatka
# Processing Record 38 of Set 11 | beloha
# Processing Record 39 of Set 11 | kirakira
# Processing Record 40 of Set 11 | pachino
# Processing Record 41 of Set 11 | hirara
# Processing Record 42 of Set 11 | kharp
# Processing Record 43 of Set 11 | san jose
# Processing Record 44 of Set 11 | shelburne
# Processing Record 45 of Set 11 | kangaba
# Processing Record 46 of Set 11 | ambanja
# Processing Record 47 of Set 11 | north bend
# Processing Record 48 of Set 11 | de aar
# Processing Record 49 of Set 11 | lazurne
# Processing Record 50 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 1 of Set 12 | gamboma
# Processing Record 2 of Set 12 | burica
# City not found. Skipping...
# Processing Record 3 of Set 12 | el tocuyo
# Processing Record 4 of Set 12 | muyezerskiy
# Processing Record 5 of Set 12 | amarante do maranhao
# Processing Record 6 of Set 12 | lodja
# Processing Record 7 of Set 12 | longyearbyen
# Processing Record 8 of Set 12 | bunda
# Processing Record 9 of Set 12 | energetik
# Processing Record 10 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 12 | jega
# Processing Record 12 of Set 12 | bom jesus
# Processing Record 13 of Set 12 | puerto madero
# Processing Record 14 of Set 12 | sangueya
# Processing Record 15 of Set 12 | babstovo
# Processing Record 16 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 17 of Set 12 | nanakuli
# Processing Record 18 of Set 12 | botwood
# Processing Record 19 of Set 12 | richards bay
# Processing Record 20 of Set 12 | sodertalje
# City not found. Skipping...
# Processing Record 21 of Set 12 | caluquembe
# Processing Record 22 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 12 | saint-ambroise
# Processing Record 24 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 12 | koumac
# Processing Record 26 of Set 12 | wanning
# Processing Record 27 of Set 12 | gandajika
# Processing Record 28 of Set 12 | bukachacha
# Processing Record 29 of Set 12 | gryazi
# Processing Record 30 of Set 12 | karratha
# Processing Record 31 of Set 12 | san quintin
# Processing Record 32 of Set 12 | mount pleasant
# Processing Record 33 of Set 12 | synya
# Processing Record 34 of Set 12 | tura
# Processing Record 35 of Set 12 | kargat
# Processing Record 36 of Set 12 | hanzhong
# Processing Record 37 of Set 12 | kenai
# Processing Record 38 of Set 12 | sao felix do xingu
# Processing Record 39 of Set 12 | wauconda
# Processing Record 40 of Set 12 | mehamn
# Processing Record 41 of Set 12 | vredendal
# Processing Record 42 of Set 12 | khasan
# Processing Record 43 of Set 12 | rio grande
# Processing Record 44 of Set 12 | sayyan
# Processing Record 45 of Set 12 | ozinki
# Processing Record 46 of Set 12 | charters towers
# Processing Record 47 of Set 12 | paamiut
# Processing Record 48 of Set 12 | husavik
# Processing Record 49 of Set 12 | newport
# Processing Record 50 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 13 | puro
# Processing Record 2 of Set 13 | menongue
# Processing Record 3 of Set 13 | ocos
# Processing Record 4 of Set 13 | fortuna
# Processing Record 5 of Set 13 | tieli
# Processing Record 6 of Set 13 | phalaborwa
# Processing Record 7 of Set 13 | chauk
# Processing Record 8 of Set 13 | charagua
# Processing Record 9 of Set 13 | bilibino
# Processing Record 10 of Set 13 | temyasovo
# Processing Record 11 of Set 13 | busembatia
# Processing Record 12 of Set 13 | rio brilhante
# Processing Record 13 of Set 13 | sigulda
# Processing Record 14 of Set 13 | faanui
# Processing Record 15 of Set 13 | savigny-le-temple
# Processing Record 16 of Set 13 | jacareacanga
# Processing Record 17 of Set 13 | manggar
# Processing Record 18 of Set 13 | jijiang
# Processing Record 19 of Set 13 | fairlie
# Processing Record 20 of Set 13 | tucurui
# Processing Record 21 of Set 13 | sao gabriel
# Processing Record 22 of Set 13 | bubaque
# Processing Record 23 of Set 13 | new iberia
# Processing Record 24 of Set 13 | natal
# Processing Record 25 of Set 13 | morehead
# Processing Record 26 of Set 13 | navashino
# Processing Record 27 of Set 13 | pingzhuang
# Processing Record 28 of Set 13 | fuengirola
# Processing Record 29 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 30 of Set 13 | tuatapere
# Processing Record 31 of Set 13 | kargopol
# Processing Record 32 of Set 13 | rossosh
# Processing Record 33 of Set 13 | smolenka
# Processing Record 34 of Set 13 | karema
# Processing Record 35 of Set 13 | mindelo
# Processing Record 36 of Set 13 | vila
# Processing Record 37 of Set 13 | ozernovskiy
# Processing Record 38 of Set 13 | astana
# Processing Record 39 of Set 13 | eirunepe
# Processing Record 40 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 13 | vikulovo
# Processing Record 42 of Set 13 | mount isa
# Processing Record 43 of Set 13 | plettenberg bay
# Processing Record 44 of Set 13 | buin
# Processing Record 45 of Set 13 | mayfield
# Processing Record 46 of Set 13 | jiazi
# Processing Record 47 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 48 of Set 13 | nantucket
# Processing Record 49 of Set 13 | kikwit
# Processing Record 50 of Set 13 | susanville
# Processing Record 1 of Set 14 | beyneu
# Processing Record 2 of Set 14 | fort nelson
# Processing Record 3 of Set 14 | yulara
# Processing Record 4 of Set 14 | sorong
# Processing Record 5 of Set 14 | muros
# Processing Record 6 of Set 14 | oranjemund
# Processing Record 7 of Set 14 | matara
# Processing Record 8 of Set 14 | kamaishi
# Processing Record 9 of Set 14 | tautira
# Processing Record 10 of Set 14 | dandong
# Processing Record 11 of Set 14 | poum
# Processing Record 12 of Set 14 | nemuro
# Processing Record 13 of Set 14 | hamilton
# Processing Record 14 of Set 14 | reichenbach
# Processing Record 15 of Set 14 | makasar
# Processing Record 16 of Set 14 | kutum
# Processing Record 17 of Set 14 | parkhill
# Processing Record 18 of Set 14 | yichang
# Processing Record 19 of Set 14 | zhangjiakou
# Processing Record 20 of Set 14 | mwanza
# Processing Record 21 of Set 14 | peniche
# Processing Record 22 of Set 14 | dakar
# Processing Record 23 of Set 14 | benghazi
# Processing Record 24 of Set 14 | hoi an
# Processing Record 25 of Set 14 | kaduna
# Processing Record 26 of Set 14 | lockhart
# Processing Record 27 of Set 14 | auki
# Processing Record 28 of Set 14 | morondava
# Processing Record 29 of Set 14 | itoman
# Processing Record 30 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 14 | piterka
# Processing Record 33 of Set 14 | beinamar
# Processing Record 34 of Set 14 | jiaojiang
# Processing Record 35 of Set 14 | pisco
# Processing Record 36 of Set 14 | monte azul
# Processing Record 37 of Set 14 | alice
# Processing Record 38 of Set 14 | avera
# Processing Record 39 of Set 14 | kargasok
# Processing Record 40 of Set 14 | chontalpa
# Processing Record 41 of Set 14 | terekli-mekteb
# Processing Record 42 of Set 14 | fowa
# Processing Record 43 of Set 14 | orsk
# Processing Record 44 of Set 14 | myanaung
# Processing Record 45 of Set 14 | faya
# Processing Record 46 of Set 14 | malanville
# Processing Record 47 of Set 14 | liling
# Processing Record 48 of Set 14 | mayumba
# Processing Record 49 of Set 14 | praya
# Processing Record 50 of Set 14 | mahibadhoo
# Processing Record 1 of Set 15 | matamoros
# Processing Record 2 of Set 15 | sisimiut
# Processing Record 3 of Set 15 | yerbogachen
# Processing Record 4 of Set 15 | topaipi
# Processing Record 5 of Set 15 | bozeman
# Processing Record 6 of Set 15 | paranagua
# Processing Record 7 of Set 15 | madimba
# Processing Record 8 of Set 15 | opportunity
# Processing Record 9 of Set 15 | katha
# City not found. Skipping...
# Processing Record 10 of Set 15 | victoria point
# Processing Record 11 of Set 15 | naze
# Processing Record 12 of Set 15 | sinjah
# City not found. Skipping...
# Processing Record 13 of Set 15 | san rafael
# Processing Record 14 of Set 15 | sucua
# Processing Record 15 of Set 15 | tucumcari
# Processing Record 16 of Set 15 | raymond terrace
# Processing Record 17 of Set 15 | honiara
# Processing Record 18 of Set 15 | haines junction
# Processing Record 19 of Set 15 | tygda
# Processing Record 20 of Set 15 | iracoubo
# Processing Record 21 of Set 15 | oussouye
# Processing Record 22 of Set 15 | bibiani
# Processing Record 23 of Set 15 | antalaha
# Processing Record 24 of Set 15 | makhinjauri
# Processing Record 25 of Set 15 | hambantota
# Processing Record 26 of Set 15 | abha
# Processing Record 27 of Set 15 | pontes e lacerda
# Processing Record 28 of Set 15 | amambai
# Processing Record 29 of Set 15 | jimma
# Processing Record 30 of Set 15 | yeletskiy
# City not found. Skipping...
# Processing Record 31 of Set 15 | sembe
# Processing Record 32 of Set 15 | wielun
# Processing Record 33 of Set 15 | bandarbeyla
# Processing Record 34 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 35 of Set 15 | port macquarie
# Processing Record 36 of Set 15 | bintulu
# Processing Record 37 of Set 15 | labuhan
# Processing Record 38 of Set 15 | santa luzia
# Processing Record 39 of Set 15 | makakilo city
# Processing Record 40 of Set 15 | gwembe
# Processing Record 41 of Set 15 | yanam
# Processing Record 42 of Set 15 | bud
# Processing Record 43 of Set 15 | ayr
# Processing Record 44 of Set 15 | huarmey
# Processing Record 45 of Set 15 | chicama
# Processing Record 46 of Set 15 | coihaique
# Processing Record 47 of Set 15 | verkhnyaya inta
# Processing Record 48 of Set 15 | gayny
# Processing Record 49 of Set 15 | cheney
# Processing Record 50 of Set 15 | tagab
# Processing Record 1 of Set 16 | kokkola
# Processing Record 2 of Set 16 | singleton
# Processing Record 3 of Set 16 | tornio
# Processing Record 4 of Set 16 | lingao
# Processing Record 5 of Set 16 | flin flon
# Processing Record 6 of Set 16 | mamallapuram
# Processing Record 7 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 16 | fecamp
# Processing Record 9 of Set 16 | tazmalt
# Processing Record 10 of Set 16 | khatassy
# Processing Record 11 of Set 16 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 16 | alanya
# Processing Record 13 of Set 16 | stephenville
# Processing Record 14 of Set 16 | atlantic beach
# Processing Record 15 of Set 16 | hailey
# Processing Record 16 of Set 16 | stulovo
# Processing Record 17 of Set 16 | awjilah
# Processing Record 18 of Set 16 | kiunga
# Processing Record 19 of Set 16 | ola
# Processing Record 20 of Set 16 | tasbuget
# City not found. Skipping...
# Processing Record 21 of Set 16 | kayerkan
# Processing Record 22 of Set 16 | kununurra
# Processing Record 23 of Set 16 | ugoofaaru
# Processing Record 24 of Set 16 | grand gaube
# Processing Record 25 of Set 16 | comodoro rivadavia
# Processing Record 26 of Set 16 | bilma
# Processing Record 27 of Set 16 | el sauzal
# Processing Record 28 of Set 16 | kanniyakumari
# Processing Record 29 of Set 16 | tiarei
# Processing Record 30 of Set 16 | hualmay
# Processing Record 31 of Set 16 | kigoma
# Processing Record 32 of Set 16 | radford
# Processing Record 33 of Set 16 | batagay-alyta
# Processing Record 34 of Set 16 | kotma
# Processing Record 35 of Set 16 | ushtobe
# Processing Record 36 of Set 16 | banki
# Processing Record 37 of Set 16 | spassk
# Processing Record 38 of Set 16 | sestri levante
# Processing Record 39 of Set 16 | santiago de cuba
# Processing Record 40 of Set 16 | sakaiminato
# Processing Record 41 of Set 16 | yatou
# Processing Record 42 of Set 16 | tena
# Processing Record 43 of Set 16 | konstantinovka
# Processing Record 44 of Set 16 | estelle
# Processing Record 45 of Set 16 | priyutnoye
# Processing Record 46 of Set 16 | honjo
# Processing Record 47 of Set 16 | mareeba
# Processing Record 48 of Set 16 | bereznehuvate
# Processing Record 49 of Set 16 | arukutti
# Processing Record 50 of Set 16 | akyab
# Processing Record 1 of Set 17 | priiskovyy
# Processing Record 2 of Set 17 | aojiang
# Processing Record 3 of Set 17 | bastrop
# Processing Record 4 of Set 17 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 17 | sao filipe
# Processing Record 6 of Set 17 | praia
# Processing Record 7 of Set 17 | lorengau
# Processing Record 8 of Set 17 | tabuk
# Processing Record 9 of Set 17 | leh
# Processing Record 10 of Set 17 | morant bay
# Processing Record 11 of Set 17 | chipata
# Processing Record 12 of Set 17 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 17 | safwah
# City not found. Skipping...
# Processing Record 14 of Set 17 | maghama
# City not found. Skipping...
# Processing Record 15 of Set 17 | santa cruz del norte
# Processing Record 16 of Set 17 | brainerd
# Processing Record 17 of Set 17 | goure
# Processing Record 18 of Set 17 | zhicheng
# Processing Record 19 of Set 17 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 17 | solwezi
# Processing Record 21 of Set 17 | nizhniy kuranakh
# Processing Record 22 of Set 17 | labrea
# Processing Record 23 of Set 17 | gizo
# Processing Record 24 of Set 17 | barguzin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 765

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Qostanay      KZ  53.1667   63.5833     14.29        73           0
# 1   Camacha      PT  33.0833  -16.3333     63.54        82          40
# 2   Rikitea      PF -23.1203 -134.9692     79.57        67         100
# 3  Tomatlan      MX  19.9333 -105.2500     68.90        83          87
# 4    Atuona      PF  -9.8000 -139.0333     79.09        75          30
#
#    Wind Speed Current Description
# 0        8.95           clear sky
# 1       26.46    scattered clouds
# 2       13.73     overcast clouds
# 3        2.51     overcast clouds
# 4       21.05    scattered clouds
